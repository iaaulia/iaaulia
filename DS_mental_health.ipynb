# %% [markdown]
# <a href="https://colab.research.google.com/github/iaaulia/iaaulia/blob/main/DS_mental_health.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = pd.read_csv('/content/mental_health_remote_workers.csv')

# 1. Tampilkan jumlah data dalam format (baris, kolom)
print("Jumlah data (baris, kolom):", data.shape)
# print("-" * 50) # Separator for clarity

# 2. Tampilkan informasi tipe data setiap kolom dan jumlah nilai non-null
print("\nInformasi tipe data dan jumlah nilai non-null:")
print(data.info())
print("-" * 50) # Separator for clarity

# # 3. Generate statistik deskriptif untuk kolom numerik
# print("\nStatistik deskriptif kolom numerik:")
# print(data.describe())
# # print("-" * 50) # Separator for clarity

# # 4. Generate statistik deskriptif untuk kolom kategorikal
# print("\nStatistik deskriptif kolom kategorik:")
# print(data.describe(include=['object']))
# print("-" * 50) # Separator for clarity

# print("\nStatistik deskriptif kolom boolean:")
# print(data.describe(include=['boolean']))
# print("-" * 50) # Separator for clarity

# 5. Tampilkan 5 baris pertama dan akhir data
print("\n5 baris pertama data:")
print(data.head())
print("-" * 50) # Separator for clarity

print("\n5 baris akhir data:")
print(data.tail())
print("-" * 50) # Separator for clarity

# 6. Tampilkan jumlah nilai unik untuk setiap kolom
print("\nJumlah nilai unik untuk setiap kolom:")
for column in data.columns:
  print(f"{column}: {data[column].nunique()}")
print("-" * 50) # Separator for clarity

# 7. Lakukan encoding untuk kolom kategorikal
print("\nMelakukan skema pengkodean kolom kategorikal:")
data['Gender'] = data['Gender'].map({'Male':1, 'Female':2})

# print("\nData setelah encoding:")
# print(data.head())
# Out:
# Jumlah data (baris, kolom): (100, 20)
#
# Informasi tipe data dan jumlah nilai non-null:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Employee_ID                       100 non-null    int64
#  1   Name                              100 non-null    object
#  2   Age                               100 non-null    int64
#  3   Gender                            100 non-null    object
#  4   Country                           100 non-null    object
#  5   Job_Role                          100 non-null    object
#  6   Experience_Years                  100 non-null    float64
#  7   Work_Mode                         100 non-null    object
#  8   Hours_Worked_Per_Week             100 non-null    float64
#  9   Productivity_Score                100 non-null    float64
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2072281176.py in <cell line: 0>()
#      11
#      12     # Plot KDE untuk kolom tersebut
# ...
